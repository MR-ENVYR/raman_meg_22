# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
#drive.flush_and_unmount()
# Out:
# Mounted at /content/gdrive/

# %%
cd 'gdrive/MyDrive/Megathon_22/data'
# Out:
# [Errno 2] No such file or directory: 'gdrive/MyDrive/Megathon_22/data'
# /content

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import math

# %%
foreground = plt.imread("charminar.jpg")
background = plt.imread("2w.jpg")
foreground1 = plt.imread("i2.jpg")
foreground2 = plt.imread("i1.jpg")
foreground3 = plt.imread("i3.jpg")
foreground4 = plt.imread("i4.jpg")
foreground5 = plt.imread("i5.jpg")
foreground6 = plt.imread("i7.jpg")
foreground7 = plt.imread("i6.jpg")
foreground8 = plt.imread("i8.jpg")

# %%
background=cv2.resize(background,(24000,16000))

# %%
foreground=cv2.resize(foreground,(3600,5000))
foreground1=cv2.resize(foreground1,(4000,2000))
foreground2=cv2.resize(foreground2,(4000,2000))
foreground3=cv2.resize(foreground3,(4000,2000))
foreground4=cv2.resize(foreground4,(4000,2000))
foreground5=cv2.resize(foreground5,(4000,2000))
foreground6=cv2.resize(foreground6,(4000,2000))
foreground7=cv2.resize(foreground7,(4000,2000))
foreground8=cv2.resize(foreground8,(4000,2000))

# %%
foreground = Image.fromarray(foreground)
foreground1 = Image.fromarray(foreground1)
foreground2 = Image.fromarray(foreground2)
foreground3 = Image.fromarray(foreground3)
foreground4 = Image.fromarray(foreground4)
foreground5 = Image.fromarray(foreground5)
foreground6 = Image.fromarray(foreground6)
foreground7= Image.fromarray(foreground7)
foreground8 = Image.fromarray(foreground8)

# %%
background = Image.fromarray(background)

# %%
foreground = foreground.convert("RGBA")
background = background.convert("RGBA")
foreground1 = foreground1.convert("RGBA")
foreground2 = foreground2.convert("RGBA")
foreground3 = foreground3.convert("RGBA")
foreground4 = foreground4.convert("RGBA")
foreground5 = foreground5.convert("RGBA")
foreground6 = foreground6.convert("RGBA")
foreground7 = foreground7.convert("RGBA")
foreground8 = foreground8.convert("RGBA")

# %%
# Calculate width to be at the center
width = int((background.width)/2 - (foreground.width)/2) 
  
# Calculate height to be at the center
height = int((background.height)/2 - (foreground.height)/2)
  
# Paste the frontImage at (width, height)
background.paste(foreground, (width, height), foreground)

# %%
r = background.width/4
width = int((background.width)/2 - (foreground.width)/2) 
height = int((background.height)/2 - (foreground.height)/2)
center = [width, height]
theta = math.pi/4

# %%
background.paste(foreground1, (int(center[0]-r*math.cos(theta)), int(center[1]-r*math.sin(theta))), foreground1)

# %%
background.paste(foreground2, (int(center[0]-r*math.cos(2*theta)), int(center[1]-r*math.sin(2*theta))), foreground2)

# %%
background.paste(foreground3, (int(center[0]-r*math.cos(3*theta)), int(center[1]-r*math.sin(3*theta))), foreground3)

# %%
background.paste(foreground4, (int(center[0]-r*math.cos(4*theta)), int(center[1]-r*math.sin(4*theta))), foreground4)

# %%
background.paste(foreground5, (int(center[0]-r*math.cos(5*theta)), int(center[1]-r*math.sin(5*theta))), foreground5)

# %%
background.paste(foreground6, (int(center[0]-r*math.cos(6*theta)), int(center[1]-r*math.sin(6*theta))), foreground6)

# %%
background.paste(foreground7, (int(center[0]-r*math.cos(7*theta)), int(center[1]-r*math.sin(7*theta))), foreground7)

# %%
background.paste(foreground8, (int(center[0]-r*math.cos(8*theta)), int(center[1]-r*math.sin(8*theta))), foreground8)

# %%
plt.imshow(background)

# %% [markdown]
# Video collage link
# https://editor.p5js.org/sumalata1510/sketches/Zy1279Uu9
